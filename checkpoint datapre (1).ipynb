# %%
import numpy as np
import pandas as pd
data=pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data=data.drop("Cabin",axis=1)

# %%
data=data.drop("PassengerId",axis=1)

# %%
data=data.drop("Ticket",axis=1)

# %%
data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
data['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(data['Age'])
plt.show()

# %%
embarked_count=[644,168,77]
department_left=['Southampton','Cherbourg','Queenstown']
explode=[0,0.1,0.2]
fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(embarked_count, explode=explode,labels=department_left,autopct='%1.1f%%',shadow=True, startangle=150)
ax1.axis('equal')
plt.show()

# %%
g=sns.FacetGrid(data,col='Embarked')
g.map(sns.countplot,'Survived')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(data,col='Sex')
g.map(plt.hist,'Age',bins=80)

# %%
g=sns.FacetGrid(data,col='Sex')
g.map(sns.countplot, 'Survived')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
fig=plt.figure(figsize=(15,7))
sns.countplot(x='Embarked',data=data)
plt.show()

# %%
sns.countplot(data = data, x = 'Pclass', hue ='Survived',palette='bwr')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
data[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
group=data[data["Survived"]==1][['Pclass','Survived']].groupby(['Pclass'],as_index=True).count()

# %%
def plot_correlation_map( df ):
    corr= df.corr()

# %%
x=pd.get_dummies(data["Sex"])
data=data.drop("Sex",axis=1)
data=data.join(x)
data.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                            Braund, Mr. Owen Harris  22.0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2         1       3                             Heikkinen, Miss. Laina  26.0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4         0       3                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch     Fare Embarked  female  male
# 0      1      0   7.2500        S       0     1
# 1      1      0  71.2833        C       1     0
# 2      0      0   7.9250        S       1     0
# 3      1      0  53.1000        S       1     0
# 4      0      0   8.0500        S       0     1

# %%
y=pd.get_dummies(data["Embarked"])
data=data.drop("Embarked",axis=1)
data=data.join(y)
data.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                            Braund, Mr. Owen Harris  22.0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2         1       3                             Heikkinen, Miss. Laina  26.0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4         0       3                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch     Fare  female  male  C  Q  S
# 0      1      0   7.2500       0     1  0  0  1
# 1      1      0  71.2833       1     0  1  0  0
# 2      0      0   7.9250       1     0  0  0  1
# 3      1      0  53.1000       1     0  0  0  1
# 4      0      0   8.0500       0     1  0  0  1

# %%
from sklearn.preprocessing import MinMaxScaler
MM_scaler = MinMaxScaler()
MM_scaler.fit(data[['Age']])
data['Age_MM'] = MM_scaler.fit_transform(data[['Age']])
print(data[['Age_MM','Age']].head())
# Out:
#      Age_MM   Age
# 0  0.271174  22.0
# 1  0.472229  38.0
# 2  0.321438  26.0
# 3  0.434531  35.0
# 4  0.434531  35.0

# %%
data.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                            Braund, Mr. Owen Harris  22.0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2         1       3                             Heikkinen, Miss. Laina  26.0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4         0       3                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch     Fare  female  male  C  Q  S    Age_MM
# 0      1      0   7.2500       0     1  0  0  1  0.271174
# 1      1      0  71.2833       1     0  1  0  0  0.472229
# 2      0      0   7.9250       1     0  0  0  1  0.321438
# 3      1      0  53.1000       1     0  0  0  1  0.434531
# 4      0      0   8.0500       0     1  0  0  1  0.434531

# %%
data=data.drop('Age',axis=1)
data.head()
# Out:
#    Survived  Pclass                                               Name  SibSp  \
# 0         0       3                            Braund, Mr. Owen Harris      1
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#    Parch     Fare  female  male  C  Q  S    Age_MM
# 0      0   7.2500       0     1  0  0  1  0.271174
# 1      0  71.2833       1     0  1  0  0  0.472229
# 2      0   7.9250       1     0  0  0  1  0.321438
# 3      0  53.1000       1     0  0  0  1  0.434531
# 4      0   8.0500       0     1  0  0  1  0.434531

# %%
familyMembers=data["SibSp"]+data["Parch"]
data=data.drop("SibSp",axis=1)
data=data.drop("Parch",axis=1)
data.insert(5,value=familyMembers,column="Family members")

# %%
data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Fare  female  Family members  male  C  Q  S    Age_MM
# 0   7.2500       0               1     1  0  0  1  0.271174
# 1  71.2833       1               1     0  1  0  0  0.472229
# 2   7.9250       1               0     0  0  0  1  0.321438
# 3  53.1000       1               1     0  0  0  1  0.434531
# 4   8.0500       0               0     1  0  0  1  0.434531

# %%
data=data.drop("Name",axis=1)

# %%
familyMembers=data["SibSp"]+data["Parch"]
data=data.drop("SibSp",axis=1)
data=data.drop("Parch",axis=1)
data.insert(5,value=familyMembers,column="Family members")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SibSp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-6b61c9467d65> in <module>
# ----> 1 familyMembers=data["SibSp"]+data["Parch"]
#       2 data=data.drop("SibSp",axis=1)
#       3 data=data.drop("Parch",axis=1)
#       4 data.insert(5,value=familyMembers,column="Family members")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'SibSp'

# %%
data.head()
# Out:
#    Survived  Pclass     Fare  female  Family members  male  C  Q  S    Age_MM
# 0         0       3   7.2500       0               1     1  0  0  1  0.271174
# 1         1       1  71.2833       1               1     0  1  0  0  0.472229
# 2         1       3   7.9250       1               0     0  0  0  1  0.321438
# 3         1       1  53.1000       1               1     0  0  0  1  0.434531
# 4         0       3   8.0500       0               0     1  0  0  1  0.434531

# %%
data.to_csv(r'Name.csv')
